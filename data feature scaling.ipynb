# %%
import pandas as pd

# %%
import numpy as np

# %%
test_data=pd.DataFrame({'x':np.random.randint(0,100,1000),
                        'y':np.random.randint(50,500,1000),
                        'z':np.random.randint(10,900,1000)})

# %%
test_data
# Out:
#       x    y    z
# 0     5  272  230
# 1    44  458  501
# 2    92  422  655
# 3    15  442  439
# 4    64  189  416
# ..   ..  ...  ...
# 995  59   89  414
# 996  29  243  157
# 997  77  154  778
# 998  73  215  515
# 999  12  499  796
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib inline

# %%
pl=plt.axes(projection='3d')
pl.scatter3D(test_data.x,test_data.y,test_data.z)
plt.figure()

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\envs\jennifer\lib\site-packages (1.5.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\envs\jennifer\lib\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\envs\jennifer\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\envs\jennifer\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\envs\jennifer\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.preprocessing import Normalizer

# %%
nm=Normalizer()

# %%
normal_data=nm.fit_transform(test_data)

# %%
normal_data
# Out:
# array([[0.01403537, 0.763524  , 0.64562691],
#        [0.06468483, 0.6733103 , 0.73652502],
#        [0.1172595 , 0.53786424, 0.83483667],
#        ...,
#        [0.0966336 , 0.19326719, 0.97637582],
#        [0.1297014 , 0.38199728, 0.91501674],
#        [0.01277202, 0.53110327, 0.84721083]])

# %%
normal_df=pd.DataFrame(normal_data,columns=['a','b','c'])

# %%
normal_df
# Out:
#             a         b         c
# 0    0.014035  0.763524  0.645627
# 1    0.064685  0.673310  0.736525
# 2    0.117260  0.537864  0.834837
# 3    0.024071  0.709305  0.704491
# 4    0.138714  0.409639  0.901640
# ..        ...       ...       ...
# 995  0.137996  0.208163  0.968310
# 996  0.099740  0.835753  0.539972
# 997  0.096634  0.193267  0.976376
# 998  0.129701  0.381997  0.915017
# 999  0.012772  0.531103  0.847211
#
# [1000 rows x 3 columns]

# %%
pl=plt.axes(projection='3d')
pl.scatter3D(normal_df.a,normal_df.b,normal_df.c)
plt.figure()

# %% [markdown]
# ## Missing values

# %%
data={'A':[1,2,4,5,6],'B':[10,40,np.nan,80,60],'C':[np.nan,np.nan,100,50,40]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    A     B      C
# 0  1  10.0    NaN
# 1  2  40.0    NaN
# 2  4   NaN  100.0
# 3  5  80.0   50.0
# 4  6  60.0   40.0

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False   True
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4  False  False  False

# %%
from sklearn.impute import SimpleImputer

# %%
sm=SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
sm.fit(df)
# Out:
# SimpleImputer()

# %%
sm.transform(df)
# Out:
# array([[  1.        ,  10.        ,  63.33333333],
#        [  2.        ,  40.        ,  63.33333333],
#        [  4.        ,  47.5       , 100.        ],
#        [  5.        ,  80.        ,  50.        ],
#        [  6.        ,  60.        ,  40.        ]])

# %%
sm1=SimpleImputer(missing_values=np.nan,strategy='median')

# %%
sm1.fit(df)
# Out:
# SimpleImputer(strategy='median')

# %%
sm1.transform(df)
# Out:
# array([[  1.,  10.,  50.],
#        [  2.,  40.,  50.],
#        [  4.,  50., 100.],
#        [  5.,  80.,  50.],
#        [  6.,  60.,  40.]])

# %%
sm1=SimpleImputer(missing_values=np.nan,strategy='most_freq')
